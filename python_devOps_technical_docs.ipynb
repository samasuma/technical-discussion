# %% [markdown]
# <a href="https://colab.research.google.com/github/samasuma/technical-discussion/blob/main/python_devOps_technical_docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Learning Python

# %%
def hello():
  print('Hello! Yum! It tastes delicious in here.')

# %%
hello()
# Out:
# Hello! Yum! It tastes delicious in here.
